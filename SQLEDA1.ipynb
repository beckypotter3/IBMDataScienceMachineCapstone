# %%
# !pip install sqlalchemy==1.3.9
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 84.6 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp37-cp37m-linux_x86_64.whl size=1159121 sha256=19ff7080979ca6dd921693eb42fcd9d96167455629c3386f629b35e8db0fa19f
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/03/71/13/010faf12246f72dc76b4150e6e599d13a85b4435e06fb9e51f
# Successfully built sqlalchemy
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
# ...

# %%
# %load_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5

# %%
# %sql sqlite:///my_data1.db
# Out:
# 'Connected: @my_data1.db'

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/generic.py:2882: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   both result in 0.1234 being formatted as 0.12.

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) table SPACEXTABLE already exists
# [SQL: create table SPACEXTABLE as select * from SPACEXTBL where Date is not null]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# Task 1
# %sql select distinct launch_site from SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %%
# Task 2
# %sql select * from SPACEXTABLE where launch_site like '%CCA%' limit 5;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('2010-12-08', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('2012-05-22', '7:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('2012-10-08', '0:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('2013-03-01', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %%
# Task 3
# %sql select SUM(PAYLOAD_MASS__KG_) from SPACEXTABLE where Customer = 'NASA (CRS)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(45596,)]

# %%
#Task 4
# %sql select avg(PAYLOAD_MASS__KG_) from SPACEXTABLE where Booster_Version like '%F9 v1.1%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2534.6666666666665,)]

# %%
# Task 5
# %sql select min(date) from SPACEXTABLE where Landing_Outcome = 'Success (ground pad)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-12-22',)]

# %%
# Task 6
# %sql SELECT "Booster_Version", "Landing_Outcome", "Payload_Mass__kg_" FROM SPACEXTABLE WHERE "Landing_Outcome" = 'Success (drone ship)' AND "Payload_Mass__kg_" > 4000 AND "Payload_Mass__kg_" < 6000;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1022', 'Success (drone ship)', 4696),
#  ('F9 FT B1026', 'Success (drone ship)', 4600),
#  ('F9 FT  B1021.2', 'Success (drone ship)', 5300),
#  ('F9 FT  B1031.2', 'Success (drone ship)', 5200)]

# %%
# Task 7
# %sql SELECT COUNT("*") FROM SPACEXTABLE WHERE Mission_Outcome LIKE "%Success%"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(100,)]

# %%
# Task 7
# %sql SELECT COUNT("*") FROM SPACEXTABLE WHERE Mission_Outcome LIKE "%Failure%"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(1,)]

# %%
# Task 8
# %sql SELECT "Booster_Version" FROM SPACEXTABLE WHERE "Payload_Mass__kg_" = (SELECT MAX("Payload_Mass__kg_") FROM SPACEXTABLE);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2 ',),
#  ('F9 B5 B1058.3 ',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7 ',)]

# %%
# Task 9
# %sql SELECT SUBSTR(Date,0,5) AS "Year", SUBSTR(Date, 6,2) AS "Month" , "Launch_Site", "Booster_Version", "Landing_Outcome" FROM SPACEXTABLE  WHERE SUBSTR(Date, 0, 5)='2015' AND Landing_Outcome LIKE "%Failure (drone ship)%" ORDER BY SUBSTR(Date, 6,2)
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015', '01', 'CCAFS LC-40', 'F9 v1.1 B1012', 'Failure (drone ship)'),
#  ('2015', '04', 'CCAFS LC-40', 'F9 v1.1 B1015', 'Failure (drone ship)')]

# %%
# %sql SELECT LANDING_OUTCOME as "Landing Outcome", COUNT(LANDING_OUTCOME) AS "Total Count" FROM SPACEXTABLE \
WHERE DATE BETWEEN '2010-06-04' AND '2017-03-20' \
GROUP BY  LANDING_OUTCOME \
ORDER BY COUNT(LANDING_OUTCOME) DESC ;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('No attempt', 10),
#  ('Success (drone ship)', 5),
#  ('Failure (drone ship)', 5),
#  ('Success (ground pad)', 3),
#  ('Controlled (ocean)', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Failure (parachute)', 2),
#  ('Precluded (drone ship)', 1)]
